# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def Sigmoid(x):
    return 1/(1 + np.exp(-x))

# %%
res = []
for i in range(-10, 10):
    fx = Sigmoid(i)
    res.append(fx)

# %%
plt.plot(res)
plt.show()
